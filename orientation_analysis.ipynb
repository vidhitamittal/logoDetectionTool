# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
orientation_order = ['horizontal', 'vertical', 'square']
labs_cap = ['Horizontal', 'Vertical', 'Square']

# %%
english_df = pd.read_csv('all_english_dims.csv')
eng_ori_count = english_df['orientation'].value_counts().reindex(orientation_order, fill_value = 0)
print(eng_ori_count)
# orientation     n = 339
# horizontal    231, 68.14%
# vertical       90, 26.55%
# square         17, 5.01%
# Out:
# orientation
# horizontal    231
# vertical       90
# square         17
# Name: count, dtype: int64

# %%
eng_ori_count.plot(kind = 'bar')
plt.xlabel('Orientation Type')
plt.ylabel('Count')
plt.title('Distribution of Orientations - English')
plt.xticks(ticks = range(len(labs_cap)), labels = labs_cap, rotation = 0)
plt.show()

# %%
hindi_df = pd.read_csv('all_hindi_dims.csv')
hin_ori_count = hindi_df['orientation'].value_counts().reindex(orientation_order, fill_value = 0)
print(hin_ori_count)
# orientation     n = 399
# horizontal    122, 30.58%
# vertical      259, 64.91%
# square         17, 4.26%
# Out:
# orientation
# horizontal    122
# vertical      259
# square         17
# Name: count, dtype: int64

# %%
hin_ori_count.plot(kind = 'bar')
plt.xlabel('Orientation Type')
plt.ylabel('Count')
plt.title('Distribution of Orientations - Hindi')
plt.xticks(ticks = range(len(labs_cap)), labels = labs_cap, rotation = 0)
plt.show()

# %%
eng_perc = (eng_ori_count / 339) * 100
hin_perc = (hin_ori_count / 399) * 100

combined_df = pd.DataFrame({
    'English, n = 339': eng_perc,
    'Hindi, n = 399': hin_perc
})

combined_df = combined_df.reindex(orientation_order)
print(combined_df)
combined_df.plot(kind = 'bar')
plt.xlabel('Orientation Type')
plt.ylabel('Percentage of Sample')
plt.title('Distribution of Orientations in English and Hindi')
plt.xticks(ticks = range(len(labs_cap)), labels = labs_cap, rotation = 0)
plt.legend(title = 'Language')
plt.show()
# Out:
#              English, n = 339  Hindi, n = 399
# orientation
# horizontal          68.141593       30.576441
# vertical            26.548673       64.912281
# square               5.014749        4.260652
